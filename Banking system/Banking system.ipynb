# %%
class Account:
    def __init__(self, account_number, pin, balance=0):
        self.account_number = account_number
        self.pin = pin
        self.balance = balance

    def login(self, pin):
        if pin == self.pin:
            return True
        else:
            return False

    def deposit(self, amount):
        self.balance += amount
        print(f"Deposited ₹{amount}. New balance: ₹{self.balance}")

    def withdraw(self, amount):
        if amount > self.balance:
            print("Insufficient funds")
        else:
            self.balance -= amount
            print(f"Withdrew ₹{amount}. New balance: ₹{self.balance}")

    def check_balance(self):
        print(f"Your current balance is: ₹{self.balance}")

def banking():
    accounts = {}  # Dictionary to store accounts

    while True:
        print("\nWelcome")
        print("1. Login")
        print("2. Create Account")
        print("3. Exit")

        choice = input("Enter your choice: ")

        if choice == '1':
            account_number = int(input("Enter account number: "))
            pin = int(input("Enter PIN: "))

            if account_number in accounts:
                account = accounts[account_number]
                if account.login(pin):
                    print("Login successful")
                    while True:
                        print("\nMenu:")
                        print("1. Deposit")
                        print("2. Withdraw")
                        print("3. Check Balance")
                        print("4. Logout")

                        action = input("Enter your action: ")

                        if action == '1':
                            amount = float(input("Enter amount to deposit: ₹"))
                            account.deposit(amount)
                        elif action == '2':
                            amount = float(input("Enter amount to withdraw: ₹"))
                            account.withdraw(amount)
                        elif action == '3':
                            account.check_balance()
                        elif action == '4':
                            print("Logged out!")
                            break
                        else:
                            print("Invalid action!")
                    else:
                        print("Invalid PIN!")
                else:
                    print("Account not found!")

        elif choice == '2':
            account_number = int(input("Enter a new account number: "))
            pin = int(input("Create a PIN: "))
            accounts[account_number] = Account(account_number, pin)
            print("Account created successfully")

        elif choice == '3':
            print("Thanks, visit us again!")
            break

        else:
            print("Invalid choice!")

banking()
# Out:
# Welcome
# 1. Login
# 2. Create Account
# 3. Exit
# Enter your choice: 2
# Enter a new account number: 374281
# Create a PIN: 2626
# Account created successfully!
#
# Welcome
# 1. Login
# 2. Create Account
# 3. Exit
# Enter your choice: 1
# Enter account number: 374281
# Enter PIN: 2626
# Login successful!
#
# Menu:
# 1. Deposit
# 2. Withdraw
# 3. Check Balance
# 4. Logout
# Enter your action: 3
# Your current balance is: ₹0
#
# Menu:
# 1. Deposit
# 2. Withdraw
# 3. Check Balance
# 4. Logout
# Enter your action: 1
# Enter amount to deposit: ₹1500
# Deposited ₹1500.0. New balance: ₹1500.0
#
# Menu:
# 1. Deposit
# 2. Withdraw
# 3. Check Balance
# 4. Logout
# Enter your action: 2
# Enter amount to withdraw: ₹48
# Withdrew ₹48.0. New balance: ₹1452.0
#
# Menu:
# 1. Deposit
# 2. Withdraw
# 3. Check Balance
# 4. Logout
# Enter your action: 3
# Your current balance is: ₹1452.0
#
# Menu:
# 1. Deposit
# 2. Withdraw
# 3. Check Balance
# 4. Logout
# Enter your action: 4
# Logged out!
#
# Welcome
# 1. Login
# 2. Create Account
# 3. Exit
# Enter your choice: 2
# Enter a new account number: 070826
# Create a PIN: 1212
# Account created successfully!
#
# Welcome
# 1. Login
# 2. Create Account
# 3. Exit
# Enter your choice: 1
# Enter account number: 070826
# Enter PIN: 1212
# Login successful!
#
# Menu:
# 1. Deposit
# 2. Withdraw
# 3. Check Balance
# 4. Logout
# Enter your action: 1
# Enter amount to deposit: ₹600
# Deposited ₹600.0. New balance: ₹600.0
#
# Menu:
# 1. Deposit
# 2. Withdraw
# 3. Check Balance
# 4. Logout
# Enter your action: 4
# Logged out!
#
# Welcome
# 1. Login
# 2. Create Account
# 3. Exit
# Enter your choice: 3
# Thanks, visit us again!
